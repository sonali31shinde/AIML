# %% [markdown]
# <a href="https://colab.research.google.com/github/sonali31shinde/AIML/blob/main/Session_3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visulization using Python**

# %% [markdown]
# # Agenda:
# 1. Data visualization using
#     1. Matplotlib
#     2. Seaborn

# %% [markdown]
# # **Pandas**
#
# [<img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2560px-Pandas_logo.svg.png" width="250"/>](image.png)
#
# Pandas is a plotting library? Yes! It uses matplotlib backed.
#
# Positives:
# - ✔️ Plot directly from a dataframe. No other imports.
# - ✔️ Suprisingly has a lot of plotting options.
# - ✔️ Great starting point for matplotlib plots
#
# Negatives:
# - ❌ Not interactive
# - ❌ Plain and simple

# %%
# !wget https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2.csv > /dev/null
# Out:
# --2025-11-15 05:16:49--  https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31984 (31K) [text/plain]
# Saving to: ‘air_quality_no2.csv’
#
# air_quality_no2.csv 100%[===================>]  31.23K  --.-KB/s    in 0.004s
#
# 2025-11-15 05:16:49 (8.35 MB/s) - ‘air_quality_no2.csv’ saved [31984/31984]

# %%
import pandas as pd

air_quality = pd.read_csv('air_quality_no2.csv', engine='python')
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=.5, figsize=(15, 5))
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=.9, figsize=(15, 5))
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.area(figsize=(12, 8))
# Out:
# <Axes: >

# %%
air_quality.plot.area(figsize=(12, 8), subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# #### Matplotlib: https://matplotlib.org/stable/tutorials/index
# #### Seaborn: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ## # **Matplotlib**
# ## gitub stars: 14k
#
# [<img src="https://matplotlib.org/stable/_images/sphx_glr_logos2_003.png" width="250"/>](matplotlib.png)
#
# Positives:
# - ✔️ Most solid plotting library in python.
# - ✔️ Customization to do almost anything.
# - ✔️ Widely used and other packages build off of it.
#
# Negatives:
# - ❌ Hard learn at first.
# - ❌ Complex plots can be code heavy.
# - ❌ Not best for interactive plots.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline # allows chart to show in notebook

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/anatomy.png)

# %% [markdown]
# ### Using pyplot function interface

# %%
plt.plot();

# %%
x1=[1,2,3,4,5]
y1=[50,100,150,200,250]

plt.plot(x1,y1);
plt.xlabel('x-axis');
plt.ylabel('y-axis');
plt.title('TItle for the graph');

# %%
x1=[1,2,3,4,5]
y1=[50,100,150,200,250]

plt.plot(x1,y1);

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('TItle for the graph');

# %%
plt.subplot(1,3,1)# Para1:numbe of rows, parm2:no of columns, plar3.plot number
# plt.plot(x1,y1,c='r');

plt.subplot(1,3,2)
plt.plot(y1,x1,c='b')

plt.subplot(1,3,3)
# plt.plot(y1,x1,c='y')
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)# Para1:numbe of rows, parm2:no of columns, plar3.plot number
plt.plot(x1,y1,c='r');
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,2)
plt.plot(x1,y1,c='b')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,2,3)
plt.plot(y1,x1,c='r')
plt.xlabel('y')
plt.ylabel('x')

plt.subplot(2,2,4)
plt.plot(y1,x1,c='b')
plt.xlabel('y')
plt.ylabel('x')
# Out:
# Text(0, 0.5, 'x')

# %%
import numpy as np
x= np.linspace(0,5,11) #generating linearly spaced values
y=x**2
print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y);
plt.xlabel('X label') # x axis label
plt.ylabel('Y label') # y axis label
plt.title("Plot title") # plot title
# Out:
# Text(0.5, 1.0, 'Plot title')

# %% [markdown]
# ### Alternative way and effective:

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(4,6))

axes[0].plot(x,y,'P')# plus mark for data points
axes[0].set_title('First title')

axes[1].plot(y,x,'x')# x mark for data points
axes[1].set_title('Second title')
# Out:
# Text(0.5, 1.0, 'Second title')

# %%
# separate the above code
axes[1].plot(y,x,'x')# x mark for data points
axes[1].set_title('Second title')
# Out:
# Text(0.5, 1.0, 'Second title')

# %% [markdown]
# fig#holds figures/plots

# %% [markdown]
# axes

# %%
fig.savefig('matplot_fig.png')
fig.savefig('matplt_fig_dpi.png',dpi=200) # DPI(dots per inch) for resolution of figure

# %% [markdown]
# ### Scatter plot

# %%
# create some data
x = np.linspace(0,10,100)

# %%
# using same data plot scatter
fig, ax= plt.subplots(figsize=(4,6))
ax.scatter(x,np.exp(x));

# %%
ax
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plot

# %%
# make a plot using dictionary
stationary_price = {"Pens":10,
                    "Books":8,
                    'Pencils':12
                   }

# plotting bar chart/plot
fig,ax = plt.subplots(figsize=(6,6))

ax.bar(stationary_price.keys(),
       stationary_price.values())

ax.set(title = 'Stationary store',
      xlabel = 'Various items',
      ylabel = "ItemPrices($)");

# %%
x1=[1,2,3,4,5]
y1=[50,100,150,200,250]

plt.plot(x1,y1);

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('TItle for the graph');

# %%
stationary_price = {"Pens":10,
                    "Books":8,
                    'Pencils':12
                   }
stationary_price

plt.bar(stationary_price.keys(),stationary_price.values());
plt.xlabel('Various items')
plt.ylabel('Itemprice($)')
plt.title('Stationary store');

# %% [markdown]
# ### Histogram

# %%
x = np.random.randn(1000)

# %%
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Understanding Matplotlib workflow steps:

# %%
# 0. import matplotlib and get it ready for plotting in jupyter
import matplotlib.pyplot as plt
# %matplotlib inline

# 1. Prepare data
x = [1,2,3,4]
y = [4,5,3,2]

# 2. setup the plot
fig, ax = plt.subplots(figsize=(8,6))

# 3. Plot the data
ax.plot(x,y,label='sales',
        color='red',
        linewidth=2,
        alpha=0.5,
        marker="*",
        markersize=20,
        markerfacecolor='red',
       markeredgewidth=2,
       markeredgecolor='green')

# 4. customize the plot
ax.set(title='Simple plot',
       xlabel='x-axis',
       ylabel='y-axis')

# 5. save the figure
fig.savefig('sample-plot.png',
            dpi=200)
ax.legend();

# %% [markdown]
# ### What will be output?

# %%
# create some data
x = np.linspace(0,10,100)
# plot the data
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# # **Seaborn**
# ## github stars: 9k
# [<img src="https://seaborn.pydata.org/_images/logo-wide-lightbg.svg" width="250"/>](image.png)
#
# Positives:
# - ✔️ Standard plots out of the box
# - ✔️ Perfect for statisical anaylsis.
# - ✔️ Fast to use for standard plots
#
# Negatives:
# - ❌ Built on top of matplotlib
# - ❌ Less ability to customize

# %%
import seaborn as sns

# Seaborn builtin datasets
tips = sns.load_dataset('tips')
# first 5 rows of datasets
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex', 'smoker', 'day', 'time'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from matplotlib import pyplot as plt
_df_1['total_bill'].plot(kind='hist', bins=20, title='total_bill')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# changing the aaggregation statistic to compute each bin
sns.histplot(data=tips,
             x='sex',
             stat="percent",
             discrete = False);

# %%
# changing the aaggregation statistic to compute each bin
sns.histplot(data=tips,
             x='sex',
             stat="percent",
             discrete = True);

# %%
# changing the aaggregation statistic to compute each bin
sns.histplot(data=tips,
             x='sex',
             stat='density');

# %%
sns.histplot(data=tips,
             y='tip',
             discrete=True);

# %%
sns.barplot(data=tips,x='sex',y='tip');

# %%
sns.scatterplot(data=tips,
                x="total_bill",
                y="tip");

# %%
sns.scatterplot(data=tips,
                x="total_bill",
                y="tip",
                hue="sex");
#hue parameter take column name for colour encoding

# %%
sns.scatterplot(
    data=tips, x="total_bill",
    y="tip",
    hue="size",
    size="size",
    sizes=(20, 200),
    legend="full"
);

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flights,
             x="year",
             y="passengers",
             hue="month",
             style='month',
             markers=True);#hue=color encoding, style:'-.-.-.-', marker:*,.

# %%
sns.barplot(x='sex',
            y='total_bill',
            data=tips);# x-category , y=numeric

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins = sns.load_dataset("penguins")
sns.pairplot(data=penguins);

# %%
# Adv pandas lib
- filtering dataset
- pivot table,
- sort table/column,
- merger datasets
- group column dataset

# %% [markdown]
# # **Bokeh**
#
# [<img src="https://static.bokeh.org/branding/logos/bokeh-logo@2x.jpg" width="250"/>](image.png)
#
# Positives:
# - ✔️ Interactive plots made easy.
# - ✔️ Lots of customization options.
# - ✔️ Like matplotlib but interactive
#
# Negatives:
# - ❌ like matplotlib but interactive
# - ❌ Code heavy

# %%
! pip install bokeh

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Configure Bokeh to output to the notebook
output_notebook()

# %%
# Prepare some sample data for the bar chart
x_categories = ['A', 'B', 'C', 'D', 'E']
y_values = [5, 8, 2, 7, 4]

# Create a new plot with a title, axis labels, and a range for x-axis categories
p = figure(x_range=x_categories, height=350, title="Simple Bokeh Bar Chart",
           x_axis_label='Category', y_axis_label='Value')

# Add a vertical bar renderer
p.vbar(x=x_categories, top=y_values, width=0.9, legend_label="Sample Data",
       color="olivedrab")

# Customize plot properties
p.xgrid.grid_line_color = None # Hide x-grid lines
p.y_range.start = 0 # Start y-axis from 0

# Show the results
show(p)
# Out:
#   <div id="dd9e48ca-1880-43a6-9fe0-73e8d4e1dd3c" data-root-id="p1003" style="display: contents;"></div>

# %%
# prepare some data
x = [1, 2, 3, 4, 5]
y1 = [6, 7, 2, 4, 5]
y2 = [2, 3, 4, 5, 6]
y3 = [4, 5, 5, 7, 2]

# create a new plot with a title and axis labels
p = figure(title="Multiple line example", x_axis_label="x", y_axis_label="y")

# add multiple renderers
p.line(x, y1, legend_label="Temp.", color="blue", line_width=2)
p.line(x, y2, legend_label="Rate", color="red", line_width=2)
p.line(x, y3, legend_label="Objects", color="green", line_width=2)

show(p)
# Out:
#   <div id="e52d450c-4702-4653-a235-6c1d1f7c088a" data-root-id="p1253" style="display: contents;"></div>

# %%
import numpy as np

from bokeh.plotting import figure, show

# generate some data
N = 1000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100

# generate radii and colors based on data
radii = y / 100 * 2
colors = ["#%02x%02x%02x" % (255, int(round(value * 255 / 100)), 255) for value in y]

# create a new plot with a specific size
p = figure(
    title="Vectorized colors and radii example",
    sizing_mode="stretch_width",
    max_width=1200,
    height=400,
)

# add circle renderer
p.circle(
    x,
    y,
    radius=radii,
    fill_color=colors,
    fill_alpha=0.6,
    line_color="lightgrey",
)

# show the results
show(p)
# Out:
#   <div id="d9c92dc8-5fa3-430b-a361-483b915b974e" data-root-id="p1366" style="display: contents;"></div>
